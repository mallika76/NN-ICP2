# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Convert the labels to categorical
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a  model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# train the model and record the training history
history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                    epochs=20, batch_size=128)

# plot the training and validation accuracy and loss curves
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')
plt.legend()

#plt.tight_layout()
plt.show()
# Out:
# Epoch 1/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.2503 - accuracy: 0.9258 - val_loss: 0.1065 - val_accuracy: 0.9680
# Epoch 2/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.1016 - accuracy: 0.9690 - val_loss: 0.0801 - val_accuracy: 0.9738
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0728 - accuracy: 0.9774 - val_loss: 0.0815 - val_accuracy: 0.9733
# Epoch 4/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0555 - accuracy: 0.9825 - val_loss: 0.0673 - val_accuracy: 0.9797
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0458 - accuracy: 0.9857 - val_loss: 0.0713 - val_accuracy: 0.9798
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0390 - accuracy: 0.9868 - val_loss: 0.0748 - val_accuracy: 0.9779
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0343 - accuracy: 0.9888 - val_loss: 0.0615 - val_accuracy: 0.9820
# Epoch 8/20
# 469/469 [==============================] - 3s 5ms/step - loss: 0.0278 - accuracy: 0.9903 - val_loss: 0.0736 - val_accuracy: 0.9801
# Epoch 9/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0263 - accuracy: 0.9915 - val_loss: 0.0777 - val_accuracy: 0.9816
# Epoch 10/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0272 - accuracy: 0.9909 - val_loss: 0.0691 - val_accuracy: 0.9817
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0253 - accuracy: 0.9915 - val_loss: 0.0694 - val_accuracy: 0.9819
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0202 - accuracy: 0.9931 - val_loss: 0.0639 - val_accuracy: 0.9833
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0183 - accuracy: 0.9941 - val_loss: 0.0706 - val_accuracy: 0.9815
# Epoch 14/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0189 - accuracy: 0.9934 - val_loss: 0.0728 - val_accuracy: 0.9842
# Epoch 15/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0191 - accuracy: 0.9940 - val_loss: 0.0714 - val_accuracy: 0.9831
# Epoch 16/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0181 - accuracy: 0.9941 - val_loss: 0.0725 - val_accuracy: 0.9824
# Epoch 17/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0168 - accuracy: 0.9943 - val_loss: 0.0783 - val_accuracy: 0.9831
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0145 - accuracy: 0.9949 - val_loss: 0.0898 - val_accuracy: 0.9814
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0143 - accuracy: 0.9953 - val_loss: 0.0970 - val_accuracy: 0.9809
# Epoch 20/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0153 - accuracy: 0.9949 - val_loss: 0.0909 - val_accuracy: 0.9826

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a simple neural network model
model = Sequential()
model.add(Dense(512, activation='relu', input_shape=(784,)))
model.add(Dense(512, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# train the model
model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
          epochs=20, batch_size=128)


# make a prediction on the image using the trained model
prediction = model.predict(x_test[0].reshape(1, -1))
print('Model prediction:', np.argmax(prediction))

# plot one of the images in the test data
plt.imshow(x_test[0], cmap='gray')
plt.show()
# Out:
# Epoch 1/20
# 469/469 [==============================] - 3s 4ms/step - loss: 0.2185 - accuracy: 0.9342 - val_loss: 0.1145 - val_accuracy: 0.9636
# Epoch 2/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0823 - accuracy: 0.9747 - val_loss: 0.0815 - val_accuracy: 0.9740
# Epoch 3/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0518 - accuracy: 0.9834 - val_loss: 0.0686 - val_accuracy: 0.9777
# Epoch 4/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0356 - accuracy: 0.9887 - val_loss: 0.0694 - val_accuracy: 0.9781
# Epoch 5/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0279 - accuracy: 0.9908 - val_loss: 0.0797 - val_accuracy: 0.9772
# Epoch 6/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0231 - accuracy: 0.9927 - val_loss: 0.0671 - val_accuracy: 0.9826
# Epoch 7/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0186 - accuracy: 0.9936 - val_loss: 0.0797 - val_accuracy: 0.9803
# Epoch 8/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0166 - accuracy: 0.9948 - val_loss: 0.0850 - val_accuracy: 0.9795
# Epoch 9/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0165 - accuracy: 0.9944 - val_loss: 0.0832 - val_accuracy: 0.9796
# Epoch 10/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0131 - accuracy: 0.9956 - val_loss: 0.0797 - val_accuracy: 0.9811
# Epoch 11/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0105 - accuracy: 0.9966 - val_loss: 0.0895 - val_accuracy: 0.9823
# Epoch 12/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0144 - accuracy: 0.9953 - val_loss: 0.1043 - val_accuracy: 0.9774
# Epoch 13/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0101 - accuracy: 0.9968 - val_loss: 0.0890 - val_accuracy: 0.9808
# Epoch 14/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0874 - val_accuracy: 0.9828
# Epoch 15/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.0954 - val_accuracy: 0.9815
# Epoch 16/20
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.1024 - val_accuracy: 0.9787
# Epoch 17/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0101 - accuracy: 0.9964 - val_loss: 0.1053 - val_accuracy: 0.9787
# Epoch 18/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0896 - val_accuracy: 0.9824
# Epoch 19/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0088 - accuracy: 0.9969 - val_loss: 0.0995 - val_accuracy: 0.9812
# Epoch 20/20
# 469/469 [==============================] - 2s 4ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 0.1019 - val_accuracy: 0.9819
# 1/1 [==============================] - 0s 76ms/step
# Model prediction: 7

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# normalize pixel values to range [0, 1]
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dense(512, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.show()
    plt.figure(figsize=(10,6))


    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.0737, Test accuracy: 0.9806
# 1 hidden layer with sigmoid - Test loss: 0.0656, Test accuracy: 0.9805
# 2 hidden layers with sigmoid - Test loss: 0.0820, Test accuracy: 0.9808

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout
import matplotlib.pyplot as plt
import numpy as np

# load MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# convert class labels to binary class matrices
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# create a list of models to train
models = []

# model with 1 hidden layer and tanh activation
model = Sequential()
model.add(Dense(512, activation='tanh', input_shape=(784,)))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with tanh', model))

# model with 1 hidden layer and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dense(num_classes, activation='softmax'))
models.append(('1 hidden layer with sigmoid', model))

# model with 2 hidden layers and sigmoid activation
model = Sequential()
model.add(Dense(512, activation='sigmoid', input_shape=(784,)))
model.add(Dense(512, activation='sigmoid'))
model.add(Dense(num_classes, activation='softmax'))
models.append(('2 hidden layers with sigmoid', model))

# train each model and plot loss and accuracy curves
for name, model in models:
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    history = model.fit(x_train.reshape(-1, 784), y_train, validation_data=(x_test.reshape(-1, 784), y_test),
                        epochs=20, batch_size=128, verbose=0)
    # plot loss and accuracy curves
    plt.plot(history.history['loss'], label='train_loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.plot(history.history['accuracy'], label='train_accuracy')
    plt.plot(history.history['val_accuracy'], label='val_accuracy')
    plt.title(name)
    plt.xlabel('Epoch')
    plt.legend()
    plt.figure(figsize=(10,6))
    plt.show()

    # evaluate the model on test data
    loss, accuracy = model.evaluate(x_test.reshape(-1, 784), y_test, verbose=0)
    print('{} - Test loss: {:.4f}, Test accuracy: {:.4f}'.format(name, loss, accuracy))
# Out:
# 1 hidden layer with tanh - Test loss: 0.1973, Test accuracy: 0.9425
# 1 hidden layer with sigmoid - Test loss: 0.1452, Test accuracy: 0.9545
# 2 hidden layers with sigmoid - Test loss: 0.1204, Test accuracy: 0.9618
